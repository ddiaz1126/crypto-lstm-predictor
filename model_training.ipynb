# %%
# Import Libraries
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.pipeline import Pipeline
from joblib import dump
import pandas as pd
import numpy as np 
import plotly.graph_objects as go
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from statsmodels.tsa.stattools import acf, pacf
import statsmodels.api as sm
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, root_mean_squared_error

# %%
# Import Training Data
past_data = pd.read_csv('/Users/daviddiaz/Desktop/Main/crypto-lstm-predictor/data_files/train_data.csv')
# Import Testing Data
test_data = pd.read_csv('/Users/daviddiaz/Desktop/Main/crypto-lstm-predictor/data_files/test_data.csv')

# %%
# Create a candlestick plot using Plotly
fig = go.Figure(data=[go.Candlestick(x=past_data['Date'],
                                     open=past_data['Open'],
                                     high=past_data['High'],
                                     low=past_data['Low'], 
                                     close=past_data['Close'])])

fig.update_layout(title='Ethereum Price Over Time',
                  xaxis_title='Date',
                  yaxis_title='Price (USD)')

# Show the plot
fig.show()

# %% [markdown]
# ### Statistical Analysis

# %%
# Calculate ACF and PACF
acf_values = acf(past_data['Close'], nlags=40)  # You can adjust the number of lags
pacf_values = pacf(past_data['Close'], nlags=40)  # You can adjust the number of lags

# %%
# Plot ACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(acf_values, marker='o')
plt.axhline(y=0, color='gray', linestyle='--')
plt.axhline(y=-1.96 / np.sqrt(len(past_data)), color='red', linestyle='--')  # 95% confidence interval
plt.axhline(y=1.96 / np.sqrt(len(past_data)), color='red', linestyle='--')   # 95% confidence interval
plt.title('Autocorrelation Function')
plt.xlabel('Lag')
plt.ylabel('ACF')
plt.show()

# %% [markdown]
# #### Analysis suggest that there is significant autocorrelation at these lags, therefore, the past values are strongly influencing future ones

# %%
# Plot PACF
plt.subplot(212)
plt.plot(pacf_values, marker='o')
plt.axhline(y=0, color='gray', linestyle='--')
plt.axhline(y=-1.96 / np.sqrt(len(past_data)), color='red', linestyle='--')  # 95% confidence interval
plt.axhline(y=1.96 / np.sqrt(len(past_data)), color='red', linestyle='--')   # 95% confidence interval
plt.title('Partial Autocorrelation Function')
plt.xlabel('Lag')
plt.ylabel('PACF')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analysis of the PACF test provide information that the there is no significant direct relationship betwen the series and its lags.

# %%
# Perform the ADF test
adf_result = sm.tsa.adfuller(past_data['Close'])

# Print the results
print(f"ADF Statistic: {adf_result[0]}")
print(f"p-value: {adf_result[1]}")
print(f"Critical Values:\n{adf_result[4]}")
# Out:
# ADF Statistic: -1.822704389970832
# p-value: 0.36924926889244103
# Critical Values:
# {'1%': -3.4486972813047574, '5%': -2.8696246923288418, '10%': -2.571077032068342}

# %% [markdown]
# #### With the high p-value and ADF statistic, it can be condcluded that the data is not stationary.

# %% [markdown]
# ## Making it Stationary

# %%
# Perform first differencing
data_diff = past_data['Close'].diff().dropna()

# Check ADF test on differenced data
diff_adf_result = sm.tsa.adfuller(data_diff)
print(f"Differenced ADF Statistic: {diff_adf_result[0]}")
print(f"Differenced p-value: {diff_adf_result[1]}")
# Out:
# Differenced ADF Statistic: -19.182240688129347
# Differenced p-value: 0.0

# %% [markdown]
# #### Data is stationary

# %%
# Prepare sequences
def create_sequences(data, look_back=5):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

# %%
look_back = 5
X, y = create_sequences(data_diff, look_back=look_back)

# %%
# Split into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# Scale features
scaler_X = MinMaxScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = MinMaxScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# Build LSTM model
model = Sequential([
    LSTM(100, input_shape=(look_back, 1)),
    Dense(1)
])
# Out:
# /Users/daviddiaz/anaconda3/envs/local_env/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(X_train_scaled, y_train_scaled, epochs=150, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1551 - val_loss: 0.0519
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0384 - val_loss: 0.0106
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149 - val_loss: 0.0171
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0186 - val_loss: 0.0099
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104 - val_loss: 0.0115
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - val_loss: 0.0097
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0122 - val_loss: 0.0099
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 0.0096
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0111 - val_loss: 0.0095
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - val_loss: 0.0095
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0116 - val_loss: 0.0094
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0122 - val_loss: 0.0096
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - val_loss: 0.0095
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0114 - val_loss: 0.0091
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0106 - val_loss: 0.0091
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - val_loss: 0.0090
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114 - val_loss: 0.0090
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 0.0094
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0116 - val_loss: 0.0090
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 0.0088
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - val_loss: 0.0086
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - val_loss: 0.0084
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0103 - val_loss: 0.0082
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - val_loss: 0.0082
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - val_loss: 0.0081
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - val_loss: 0.0080
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - val_loss: 0.0079
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - val_loss: 0.0079
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0078
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - val_loss: 0.0080
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080 - val_loss: 0.0074
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - val_loss: 0.0072
# Epoch 39/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - val_loss: 0.0071
# Epoch 40/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0094 - val_loss: 0.0070
# Epoch 41/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 42/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0069
# Epoch 43/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 44/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0066
# Epoch 45/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088 - val_loss: 0.0065
# Epoch 46/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 47/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085 - val_loss: 0.0063
# Epoch 48/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 49/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0083 - val_loss: 0.0061
# Epoch 50/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 51/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 52/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 53/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 54/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - val_loss: 0.0055
# Epoch 55/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 56/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - val_loss: 0.0053
# Epoch 57/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 58/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 59/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 60/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 61/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 62/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 63/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 64/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 65/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 66/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 67/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 68/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0033
# Epoch 69/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 70/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 71/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 72/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 73/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 74/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 75/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 76/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 77/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 78/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 79/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 80/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 8.0398e-04
# Epoch 81/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 7.3608e-04
# Epoch 82/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3139e-04 - val_loss: 5.3811e-04
# Epoch 83/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9467e-04 - val_loss: 4.7411e-04
# Epoch 84/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3160e-04 - val_loss: 3.7480e-04
# Epoch 85/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1338e-04 - val_loss: 3.2893e-04
# Epoch 86/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0745e-04 - val_loss: 3.6659e-04
# Epoch 87/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0984e-04 - val_loss: 2.9163e-04
# Epoch 88/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6938e-04 - val_loss: 5.6261e-04
# Epoch 89/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6120e-04 - val_loss: 1.5742e-04
# Epoch 90/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0177e-04 - val_loss: 1.3360e-04
# Epoch 91/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6555e-04 - val_loss: 1.2512e-04
# Epoch 92/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8872e-04 - val_loss: 2.2659e-04
# Epoch 93/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7332e-04 - val_loss: 1.1654e-04
# Epoch 94/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5783e-04 - val_loss: 1.4152e-04
# Epoch 95/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4597e-04 - val_loss: 1.2739e-04
# Epoch 96/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0152e-04 - val_loss: 8.3137e-05
# Epoch 97/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0136e-04 - val_loss: 6.9726e-05
# Epoch 98/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2310e-05 - val_loss: 7.0627e-05
# Epoch 99/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2059e-05 - val_loss: 7.2987e-05
# Epoch 100/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9614e-05 - val_loss: 8.9633e-05
# Epoch 101/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3248e-05 - val_loss: 9.8818e-05
# Epoch 102/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2573e-05 - val_loss: 6.0062e-05
# Epoch 103/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3198e-05 - val_loss: 1.9474e-04
# Epoch 104/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1683e-04 - val_loss: 6.1038e-05
# Epoch 105/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8824e-05 - val_loss: 6.5743e-05
# Epoch 106/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0356e-05 - val_loss: 7.9871e-05
# Epoch 107/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4169e-05 - val_loss: 5.8186e-05
# Epoch 108/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1726e-05 - val_loss: 6.0232e-05
# Epoch 109/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7994e-05 - val_loss: 8.0798e-05
# Epoch 110/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2979e-05 - val_loss: 6.3702e-05
# Epoch 111/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5773e-05 - val_loss: 6.2720e-05
# Epoch 112/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8919e-05 - val_loss: 8.0992e-05
# Epoch 113/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3826e-05 - val_loss: 9.4139e-05
# Epoch 114/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4866e-05 - val_loss: 5.8627e-05
# Epoch 115/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7961e-05 - val_loss: 7.3001e-05
# Epoch 116/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6803e-05 - val_loss: 1.2394e-04
# Epoch 117/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0839e-05 - val_loss: 1.6780e-04
# Epoch 118/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5406e-04 - val_loss: 5.8417e-05
# Epoch 119/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9408e-05 - val_loss: 9.0933e-05
# Epoch 120/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4821e-05 - val_loss: 6.9743e-05
# Epoch 121/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8539e-05 - val_loss: 6.4873e-05
# Epoch 122/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3730e-05 - val_loss: 5.4735e-05
# Epoch 123/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4486e-05 - val_loss: 5.7130e-05
# Epoch 124/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6547e-05 - val_loss: 5.5599e-05
# Epoch 125/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0780e-05 - val_loss: 5.3237e-05
# Epoch 126/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3456e-05 - val_loss: 5.3024e-05
# Epoch 127/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3337e-05 - val_loss: 4.9679e-04
# Epoch 128/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4866e-04 - val_loss: 1.0371e-04
# Epoch 129/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5826e-04 - val_loss: 2.3984e-04
# Epoch 130/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3572e-04 - val_loss: 1.6352e-04
# Epoch 131/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3293e-04 - val_loss: 3.0884e-04
# Epoch 132/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2841e-04 - val_loss: 1.1080e-04
# Epoch 133/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2019e-04 - val_loss: 1.2491e-04
# Epoch 134/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4661e-05 - val_loss: 1.3104e-04
# Epoch 135/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9386e-05 - val_loss: 2.4498e-04
# Epoch 136/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5492e-04 - val_loss: 5.7534e-05
# Epoch 137/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0783e-04 - val_loss: 1.2997e-04
# Epoch 138/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1625e-05 - val_loss: 2.2955e-04
# Epoch 139/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3006e-04 - val_loss: 1.2088e-04
# Epoch 140/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3383e-05 - val_loss: 6.4463e-05
# Epoch 141/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0553e-05 - val_loss: 1.0557e-04
# Epoch 142/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6148e-05 - val_loss: 1.0055e-04
# Epoch 143/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5189e-04 - val_loss: 1.6493e-04
# Epoch 144/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1102e-04 - val_loss: 9.7275e-05
# Epoch 145/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9339e-05 - val_loss: 5.8753e-05
# Epoch 146/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7534e-05 - val_loss: 4.9039e-05
# Epoch 147/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8226e-05 - val_loss: 6.1992e-05
# Epoch 148/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6019e-05 - val_loss: 1.0053e-04
# Epoch 149/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9025e-05 - val_loss: 6.6207e-05
# Epoch 150/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3912e-05 - val_loss: 4.9296e-05

# %%
# Print out the Loss of the model
loss = model.evaluate(X_test_scaled, y_test_scaled)
print(f"Test loss: {loss}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0895e-05
# Test loss: 2.612486423458904e-05

# %%
# Predict on the test set
y_pred = model.predict(X_test_scaled)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
# Convert predictions back to the original scale
y_pred_original_scale = scaler_y.inverse_transform(y_pred)
y_test_original_scale = scaler_y.inverse_transform(y_test_scaled.reshape(-1, 1))
# Calculate MSE
mse = mean_squared_error(y_test_original_scale, y_pred_original_scale)
print(f"Mean Squared Error (MSE): {mse}")
rmse = root_mean_squared_error(y_test_original_scale, y_pred_original_scale)
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Plot
plt.figure(figsize=(12, 6))
plt.plot(y_test_original_scale, label='Actual')
plt.plot(y_pred_original_scale, label='Predicted')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Mean Squared Error (MSE): 23.695969654630044
# Root Mean Squared Error (RMSE): 4.867850619588696

# %%
# Inverse scale the predictions
y_pred_inverse = scaler_y.inverse_transform(y_pred).flatten()

# Create a new DataFrame to store predictions aligned only with y_test
test_indices = past_data.index[look_back + train_size : look_back + train_size + len(y_pred_inverse)]
predictions_df = pd.DataFrame({'Predictions': y_pred_inverse}, index=test_indices)

# Merge predictions into the original DataFrame
past_data = past_data.merge(predictions_df, left_index=True, right_index=True, how='left')

# %%
# Get the last actual Close value before the test set starts
last_close = past_data['Close'].iloc[look_back + train_size - 1]

# Reconstruct the predicted Close values from predicted differences
predicted_close = [last_close]
for diff in y_pred_inverse:
    predicted_close.append(predicted_close[-1] + diff)

# Remove the first value (last actual close) as it was used as a starting point
predicted_close = predicted_close[1:]

# Align predictions with the correct indices in the original DataFrame
test_indices = past_data.index[look_back + train_size : look_back + train_size + len(y_pred_inverse)]
predictions_df = pd.DataFrame({'Predicted_Close': predicted_close}, index=test_indices)

# Merge the predicted Close values back into the original DataFrame
past_data = past_data.merge(predictions_df, left_index=True, right_index=True, how='left')

# %%
plt.figure(figsize=(12, 6))
plt.plot(past_data['Date'], past_data['Close'])
plt.plot(past_data['Date'], past_data['Predicted_Close'])
plt.show()

# %% [markdown]
# ### Run Model On Today's Data

# %%
test_diff = test_data['Close'].diff().dropna()
test_data['Close_Diff'] = test_data['Close'].diff().dropna()

# %%
test_diff = test_data['Close'].diff().dropna()
test_data['Close_Diff'] = test_data['Close'].diff().dropna()
test_data = test_data.dropna(subset=['Close_Diff']).copy()

X2, y2 = create_sequences(test_diff, look_back=look_back)

# %%
# Get the last 5 'Close_Diff' values
last_5_diff = test_data.head(6)['Close'].diff().dropna()

# Reshape to 5x1
last_5_diff_values = last_5_diff.values.reshape(1, 5)

last_5_diff_values
# Out:
# array([[ -42.80004883,   83.53588867,   35.53979492, -100.71484375,
#          -46.60913086]])

# %%
# Scale the test data using the same scaler used for training
test_data_scaled = scaler_X.transform(last_5_diff_values)

# %%
# Predict the Close_diff using the trained model
predicted_diff_scaled = model.predict(test_data_scaled)

# Inverse transform to get back to the original scale
predicted_diff = scaler_y.inverse_transform(predicted_diff_scaled).flatten() 
print(predicted_diff)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [-46.33556]

# %%
# Add predicted differences to the DataFrame
test_data.loc[len(test_data), 'Predicted_Close_Diff'] = pd.Series(predicted_diff.flatten()).values[0]

# Calculate the predicted Close values
test_data['Predicted_Close'] = test_data['Close'] + test_data['Predicted_Close_Diff']

# %%
last_5_diff
# Out:
# 2    -42.800049
# 3     83.535889
# 4     35.539795
# 5   -100.714844
# 6    -46.609131
# Name: Close, dtype: float64

# %%
test_data
# Out:
#                         Date         Open         High          Low  \
# 1  2024-12-13 00:00:00+00:00  3883.030029  3967.395264  3855.023682
# 2  2024-12-14 00:00:00+00:00  3910.847900  3943.278076  3826.761963
# 3  2024-12-15 00:00:00+00:00  3868.441162  3971.498047  3832.096680
# 4  2024-12-16 00:00:00+00:00  3951.652832  4106.955566  3882.705322
# 5  2024-12-17 00:00:00+00:00  3987.333984  4040.337891  3849.286621
# 6  2024-12-18 00:00:00+00:00  3893.431396  3899.151611  3815.861572
#
#          Close       Volume  Dividends  Stock Splits stock_name  sector  \
# 1  3911.205322  34895127659        0.0           0.0    ETH-USD     NaN
# 2  3868.405273  28756190559        0.0           0.0    ETH-USD     NaN
# 3  3951.941162  25069616984        0.0           0.0    ETH-USD     NaN
# 4  3987.480957  46536359669        0.0           0.0    ETH-USD     NaN
# 5  3886.766113  35418700472        0.0           0.0    ETH-USD     NaN
# 6  3840.156982  35752497152        0.0           0.0    ETH-USD     NaN
#
#    industry    market_cap  Close_Diff  Predicted_Close_Diff  Predicted_Close
# 1       NaN  462554857472   28.103760                   NaN              NaN
# 2       NaN  462554857472  -42.800049                   NaN              NaN
# 3       NaN  462554857472   83.535889                   NaN              NaN
# 4       NaN  462554857472   35.539795                   NaN              NaN
# 5       NaN  462554857472 -100.714844                   NaN              NaN
# 6       NaN  462554857472  -46.609131             -46.33556      3793.821423

# %%
predicted_df = test_data.tail(1)

# %%
fig, ax1 = plt.subplots(figsize=(15, 6))

# Plotting the Actual Close on the primary y-axis
ax1.plot(test_data['Date'], test_data['Close'], color='blue', label='Actual Close')
ax1.scatter(test_data['Date'], test_data['Predicted_Close'], color='blue', marker='D', label="Predicted Close")
ax1.set_xlabel('Date')
ax1.set_ylabel('Close', color='blue')
ax1.tick_params('y', colors='blue')
# Calculate Mean Squared Error
mse_close = mean_squared_error(predicted_df['Close'], predicted_df['Predicted_Close'])

# Creating a second y-axis to plot the Predicted Close Difference
ax2 = ax1.twinx()
ax2.plot(test_data['Date'], test_data['Close_Diff'], color='orange', label="Actual Close Difference")
ax2.scatter(test_data['Date'], test_data['Predicted_Close_Diff'], color='orange', marker='D', label="Predicted Close Difference")
ax2.set_ylabel('Close Difference', color='orange')
ax2.tick_params('y', colors='orange')
mse_close_diff = mean_squared_error(predicted_df['Close_Diff'], predicted_df['Predicted_Close_Diff'])

print(f"Mean Squared Error for Close: {mse_close}")
print(f"Mean Squared Error for Close_Diff: {mse_close_diff}")

plt.xticks(rotation=45)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()
# Out:
# Mean Squared Error for Close: 2146.9841061468614
# Mean Squared Error for Close_Diff: 0.07484109992219601

# %%
# Calculate the variance of the actual values
variance_close = np.var(test_data['Close'])
variance_close_diff = np.var(test_data['Close_Diff'])

# Calculate the percentage of error
percentage_error_close = (mse_close / variance_close) * 100
percentage_error_close_diff = (mse_close_diff / variance_close_diff) * 100

print(f"Percentage Error for Close: {percentage_error_close:.2f}%")
print(f"Percentage Error for Close_Diff: {percentage_error_close_diff:.3f}%")
# Out:
# Percentage Error for Close: 86.58%
# Percentage Error for Close_Diff: 0.002%

# %% [markdown]
# # Save Components

# %%
# Save MinMaxScalar and LSTM
pipeline = Pipeline(steps=[
    ('scaler', scaler_X),
    ('model', model)
])

# Save the pipeline to a pickle file
dump(pipeline, 'model_pipeline.pkl')
# Out:
# ['model_pipeline.pkl']
